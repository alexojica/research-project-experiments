# %%
from options import args_parser
import sys
from federated_main import main as fed_main
from baseline_main import main

# %%
# # run mnist cgan experiments
# sys.argv = [
#     'script_name',  # Name of the script
#     '--model=cgan',
#     '--dataset=mnist',
#     '--epochs', f'{30}',
#     '--gpu=cuda:0',
#     '--lr', '0.0002',
#     '--testevery=5'
# ]

# # Parse the arguments
# args = args_parser()
# print(args)

# main(args)

# %%
# sys.argv = [
#     'script_name',  # Name of the script
#     '--model=cgan',
#     '--dataset=mnist',
#     '--epochs', f'{250}',
#     '--gpu=cuda:0',
#     '--lr', '0.0002',
#     '--local_ep', '1',
#     '--testevery=5'
# ]

# # Parse the arguments
# args = args_parser()
# print(args)

# fed_main(args)

# %%
# # run mnist non-iid cgan experiments
# sys.argv = [
#     'script_name',  # Name of the script
#     '--model=cgan',
#     '--dataset=mnist',
#     '--epochs', f'{500}',
#     '--gpu=cuda:0',
#     '--lr', '0.0002',
#     '--local_ep', '1',
#     '--iid=0'
# ]

# # Parse the arguments
# args = args_parser()
# print(args)

# fed_main(args)

# %%
# run cgan cifar experiments
sys.argv = [
    'script_name',  # Name of the script
    '--model=cgan',
    '--dataset=cifar',
    '--epochs', f'{40}',
    '--lr', '0.0002',
    '--gpu=cuda:0',
    f'--noise={100}',
    '--testevery=5'
]

# Parse the arguments
args = args_parser()
print(args)

main(args)
# Out:
# Namespace(epochs=250, num_users=100, frac=0.1, local_ep=10, local_bs=10, lr=0.0002, momentum=0.5, model='cgan', kernel_num=9, kernel_sizes='3,4,5', num_channels=1, norm='batch_norm', num_filters=32, max_pool='True', dataset='cifar', num_classes=10, gpu='cuda:0', optimizer='sgd', iid=1, dirichlet=0.5, unequal=0, noise=100, stopping_rounds=10, verbose=1, seed=1, testevery=5)
# Files already downloaded and verified
# Files already downloaded and verified
# GeneratorCIFAR(
#   (fc): Sequential(
#     (0): Linear(in_features=110, out_features=8192, bias=True)
#     (1): BatchNorm1d(8192, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.1)
#   )
#   (conv_layers): Sequential(
#     (0): Conv2d(128, 128, kernel_size=(4, 4), stride=(1, 1), padding=(2, 2))
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.1)
#     (3): ConvTranspose2d(128, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (4): BatchNorm2d(128, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#     (5): LeakyReLU(negative_slope=0.1)
#     (6): Conv2d(128, 128, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#     (7): BatchNorm2d(128, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#     (8): LeakyReLU(negative_slope=0.1)
#     (9): ConvTranspose2d(128, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (10): BatchNorm2d(128, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#     (11): LeakyReLU(negative_slope=0.1)
#     (12): Conv2d(128, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (13): BatchNorm2d(128, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#     (14): LeakyReLU(negative_slope=0.1)
#     (15): Conv2d(128, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (16): BatchNorm2d(128, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#     (17): LeakyReLU(negative_slope=0.1)
#     (18): Conv2d(128, 3, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (19): Tanh()
#   )
# )
# Progress overall:   0%|                                                                                                                                                                                                 | 0/250 [00:00<?, ?it/s]C:\Users\aojic\Documents\Pycharm-Projects\Federated-Learning-PyTorch\venv\lib\site-packages\torch\autograd\graph.py:744: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\aten\src\ATen\native\cudnn\Conv_v8.cpp:919.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# C:\Users\aojic\Documents\Pycharm-Projects\Federated-Learning-PyTorch\venv\lib\site-packages\torch\nn\modules\conv.py:456: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\aten\src\ATen\native\cudnn\Conv_v8.cpp:919.)
#   return F.conv2d(input, weight, bias, self.stride,
# Progress overall:   2%|██▉                                                                                                                                                                                    | 4/250 [03:11<3:16:15, 47.87s/it]
# C:\Users\aojic\Documents\Pycharm-Projects\Federated-Learning-PyTorch\venv\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\Users\aojic\Documents\Pycharm-Projects\Federated-Learning-PyTorch\venv\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Progress overall:   2%|███▋                                                                                                                                                                                   | 5/250 [04:43<4:19:48, 63.63s/it]
# Earth Mover's Distance: 0.36103274028307797
# Real images accuracy: 0.8041, Fake images accuracy: 0.3403
# Progress overall:   4%|███████▎                                                                                                                                                                              | 10/250 [09:26<4:13:54, 63.48s/it]
# Earth Mover's Distance: 0.2695707743574621
# Real images accuracy: 0.8041, Fake images accuracy: 0.4045
# Progress overall:   6%|██████████▉                                                                                                                                                                           | 15/250 [14:11<4:09:30, 63.71s/it]
# Earth Mover's Distance: 0.2973482672095533
# Real images accuracy: 0.8041, Fake images accuracy: 0.4527
# Progress overall:   8%|█████████████▊                                                                                                                                                                        | 19/250 [17:23<3:18:37, 51.59s/it]
# Progress overall:   8%|██████████████▌                                                                                                                                                                       | 20/250 [18:54<4:03:09, 63.43s/it]
# Earth Mover's Distance: 0.3591954890148955
# Real images accuracy: 0.8041, Fake images accuracy: 0.4467
# Progress overall:  10%|██████████████████▏                                                                                                                                                                   | 25/250 [23:44<4:04:13, 65.13s/it]
# Earth Mover's Distance: 0.3154152300712525
# Real images accuracy: 0.8041, Fake images accuracy: 0.5058
# Progress overall:  12%|█████████████████████▊                                                                                                                                                                | 30/250 [28:40<4:01:52, 65.96s/it]
# Earth Mover's Distance: 0.3150518938542242
# Real images accuracy: 0.8041, Fake images accuracy: 0.52
# Progress overall:  14%|█████████████████████████▍                                                                                                                                                            | 35/250 [33:33<3:55:32, 65.73s/it]
# Earth Mover's Distance: 0.3399967044985734
# Real images accuracy: 0.8041, Fake images accuracy: 0.4532
# Progress overall:  16%|████████████████████████████▍                                                                                                                                                         | 39/250 [36:45<3:03:25, 52.16s/it]
# Progress overall:  16%|█████████████████████████████                                                                                                                                                         | 40/250 [38:17<3:44:35, 64.17s/it]
# Earth Mover's Distance: 0.31229552989363163
# Real images accuracy: 0.8041, Fake images accuracy: 0.5304
# Progress overall:  18%|████████████████████████████████▊                                                                                                                                                     | 45/250 [43:00<3:37:11, 63.57s/it]
# Earth Mover's Distance: 0.32675079097599175
# Real images accuracy: 0.8041, Fake images accuracy: 0.577
# Progress overall:  20%|████████████████████████████████████▍                                                                                                                                                 | 50/250 [47:42<3:31:22, 63.41s/it]
# Earth Mover's Distance: 0.29994350107120243
# Real images accuracy: 0.8041, Fake images accuracy: 0.5209
# Progress overall:  22%|████████████████████████████████████████                                                                                                                                              | 55/250 [52:25<3:26:06, 63.42s/it]
# Earth Mover's Distance: 0.38969595229806875
# Real images accuracy: 0.8041, Fake images accuracy: 0.4936
# Progress overall:  24%|██████████████████████████████████████████▉                                                                                                                                           | 59/250 [55:37<2:44:04, 51.54s/it]
# Progress overall:  24%|███████████████████████████████████████████▋                                                                                                                                          | 60/250 [57:08<3:20:58, 63.47s/it]
# Earth Mover's Distance: 0.3383662626682033
# Real images accuracy: 0.8041, Fake images accuracy: 0.5304
# Progress overall:  25%|█████████████████████████████████████████████▏                                                                                                                                        | 62/250 [59:06<2:59:14, 57.20s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 17
#      14 args = args_parser()
#      15 print(args)
# ---> 17 main(args)
#
# File ~\Documents\Pycharm-Projects\Federated-Learning-PyTorch\src\baseline_main.py:235, in main(args)
#     229 ##############################################
#     230 # (2) Update G network: min E(z)[log(1- D(z))]
#     231 ##############################################
#     232 # Set generator gradients to zero.
#     233 global_model.zero_grad()
# --> 235 fake_validity, fake_aux = discriminator(fake_images)
#     236 g_loss = adversarial_loss(fake_validity, real_label)
#     237 aux_loss = F.cross_entropy(fake_aux, conditional)
#
# File ~\Documents\Pycharm-Projects\Federated-Learning-PyTorch\venv\lib\site-packages\torch\nn\modules\module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~\Documents\Pycharm-Projects\Federated-Learning-PyTorch\venv\lib\site-packages\torch\nn\modules\module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~\Documents\Pycharm-Projects\Federated-Learning-PyTorch\src\CGAN_PyTorch\cgan_pytorch\models\discriminator.py:132, in DiscriminatorCIFAR.forward(self, input)
#     131 def forward(self, input):
# --> 132     x = self.conv_layers(input)
#     133     x = self.flatten(x)
#     134     validity = self.adv_layer(x)
#
# File ~\Documents\Pycharm-Projects\Federated-Learning-PyTorch\venv\lib\site-packages\torch\nn\modules\module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~\Documents\Pycharm-Projects\Federated-Learning-PyTorch\venv\lib\site-packages\torch\nn\modules\module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~\Documents\Pycharm-Projects\Federated-Learning-PyTorch\venv\lib\site-packages\torch\nn\modules\container.py:217, in Sequential.forward(self, input)
#     215 def forward(self, input):
#     216     for module in self:
# --> 217         input = module(input)
#     218     return input
#
# File ~\Documents\Pycharm-Projects\Federated-Learning-PyTorch\venv\lib\site-packages\torch\nn\modules\module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~\Documents\Pycharm-Projects\Federated-Learning-PyTorch\venv\lib\site-packages\torch\nn\modules\module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~\Documents\Pycharm-Projects\Federated-Learning-PyTorch\venv\lib\site-packages\torch\nn\modules\batchnorm.py:155, in _BatchNorm.forward(self, input)
#     152 if self.training and self.track_running_stats:
#     153     # TODO: if statement only here to tell the jit to skip emitting this when it is None
#     154     if self.num_batches_tracked is not None:  # type: ignore[has-type]
# --> 155         self.num_batches_tracked.add_(1)  # type: ignore[has-type]
#     156         if self.momentum is None:  # use cumulative moving average
#     157             exponential_average_factor = 1.0 / float(self.num_batches_tracked)
#
# KeyboardInterrupt:

# %%
sys.argv = [
    'script_name',  # Name of the script
    '--model=cgan',
    '--dataset=cifar',
    '--epochs', f'{200}',
    '--gpu=cuda:0',
    '--lr', '0.0002',
    '--local_ep', '1',
    '--local_bs=32',
    '--num_users=100'
]

# Parse the arguments
args = args_parser()
print(args)

fed_main(args)

# %%
sys.argv = [
    'script_name',  # Name of the script
    '--model=cgan',
    '--dataset=cifar',
    '--epochs', f'{300}',
    f'--noise={100}',
    '--gpu=cuda:0',
    '--lr', '0.0002',
    '--local_ep', '1',
    '--local_bs=32',
    '--num_users=100',
    '--iid=0'
]

# Parse the arguments
args = args_parser()
print(args)

fed_main(args)
